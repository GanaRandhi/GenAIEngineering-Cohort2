# %%
! pip install numpy==1.26.4 ipykernel phidata openai ipywidgets duckduckgo-search yfinance crawl4ai lancedb sentence-transformers torch pypdf chromadb duckdb
# Out:
# Requirement already satisfied: numpy==1.26.4 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (1.26.4)
# Requirement already satisfied: ipykernel in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (6.30.1)
# Requirement already satisfied: phidata in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (2.7.10)
# Requirement already satisfied: openai in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (2.1.0)
# Requirement already satisfied: ipywidgets in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (8.1.7)
# Requirement already satisfied: duckduckgo-search in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (8.1.1)
# Requirement already satisfied: yfinance in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (0.2.58)
# Requirement already satisfied: crawl4ai in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (0.7.4)
# Requirement already satisfied: lancedb in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (0.25.1)
# Requirement already satisfied: sentence-transformers in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (5.1.1)
# Requirement already satisfied: torch in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (2.8.0)
# Requirement already satisfied: pypdf in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (6.1.1)
# Requirement already satisfied: chromadb in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (1.1.0)
# Requirement already satisfied: duckdb in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (1.4.0)
# Requirement already satisfied: comm>=0.1.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipykernel) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipykernel) (9.6.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipykernel) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: docstring-parser in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from phidata) (0.17.0)
# Requirement already satisfied: gitpython in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from phidata) (3.1.45)
# Requirement already satisfied: httpx in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from phidata) (0.28.1)
# Requirement already satisfied: pydantic in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from phidata) (2.11.10)
# Requirement already satisfied: pydantic-settings in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from phidata) (2.11.0)
# Requirement already satisfied: python-dotenv in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from phidata) (1.1.1)
# Requirement already satisfied: pyyaml in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from phidata) (6.0.3)
# Requirement already satisfied: rich in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from phidata) (14.1.0)
# Requirement already satisfied: tomli in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from phidata) (2.2.1)
# Requirement already satisfied: typer in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from phidata) (0.19.2)
# Requirement already satisfied: typing-extensions in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from phidata) (4.15.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from openai) (0.11.0)
# Requirement already satisfied: sniffio in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: click>=8.1.8 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from duckduckgo-search) (8.3.0)
# Requirement already satisfied: primp>=0.15.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from duckduckgo-search) (0.15.0)
# Requirement already satisfied: lxml>=5.3.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from duckduckgo-search) (5.4.0)
# Requirement already satisfied: pandas>=1.3.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: requests>=2.31 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from yfinance) (4.4.0)
# Requirement already satisfied: pytz>=2022.5 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from yfinance) (4.14.2)
# Requirement already satisfied: curl_cffi>=0.7 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (24.1.0)
# Requirement already satisfied: aiohttp>=3.11.11 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (3.12.15)
# Requirement already satisfied: aiosqlite~=0.20 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (0.20.0)
# Requirement already satisfied: litellm>=1.53.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (1.77.5)
# Requirement already satisfied: pillow>=10.4 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (11.3.0)
# Requirement already satisfied: playwright>=1.49.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (1.55.0)
# Requirement already satisfied: patchright>=1.49.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (1.55.2)
# Requirement already satisfied: tf-playwright-stealth>=1.1.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (1.2.0)
# Requirement already satisfied: xxhash~=3.4 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (3.6.0)
# Requirement already satisfied: rank-bm25~=0.2 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (0.2.2)
# Requirement already satisfied: snowballstemmer~=2.2 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (2.2.0)
# Requirement already satisfied: pyOpenSSL>=24.3.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (25.3.0)
# Requirement already satisfied: nltk>=3.9.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (3.9.2)
# Requirement already satisfied: fake-useragent>=2.0.3 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (2.2.0)
# Requirement already satisfied: chardet>=5.2.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (5.2.0)
# Requirement already satisfied: brotli>=1.1.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (1.1.0)
# Requirement already satisfied: humanize>=4.10.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (4.13.0)
# Requirement already satisfied: lark>=1.2.2 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (1.3.0)
# Requirement already satisfied: alphashape>=1.3.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (1.3.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from crawl4ai) (2.1.2)
# Requirement already satisfied: deprecation in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from lancedb) (2.1.0)
# Requirement already satisfied: overrides>=0.7 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from lancedb) (7.7.0)
# Requirement already satisfied: pyarrow>=16 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from lancedb) (21.0.0)
# Requirement already satisfied: lance-namespace==0.0.6 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from lancedb) (0.0.6)
# Requirement already satisfied: lance-namespace-urllib3-client in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from lance-namespace==0.0.6->lancedb) (0.0.17)
# Requirement already satisfied: pylance>=0.18.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from lance-namespace==0.0.6->lancedb) (0.38.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from sentence-transformers) (4.57.0)
# Requirement already satisfied: scikit-learn in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from sentence-transformers) (1.16.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from sentence-transformers) (0.35.3)
# Requirement already satisfied: filelock in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from torch) (3.19.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from torch) (2025.9.0)
# Requirement already satisfied: build>=1.0.3 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.35.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from chromadb) (1.23.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: importlib-resources in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from chromadb) (1.75.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from chromadb) (3.11.3)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from aiohttp>=3.11.11->crawl4ai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from aiohttp>=3.11.11->crawl4ai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from aiohttp>=3.11.11->crawl4ai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from aiohttp>=3.11.11->crawl4ai) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from aiohttp>=3.11.11->crawl4ai) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from aiohttp>=3.11.11->crawl4ai) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from aiohttp>=3.11.11->crawl4ai) (1.20.1)
# Requirement already satisfied: click-log>=0.3.2 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from alphashape>=1.3.1->crawl4ai) (0.4.0)
# Requirement already satisfied: trimesh>=3.9.8 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from alphashape>=1.3.1->crawl4ai) (4.8.3)
# Requirement already satisfied: rtree>=0.9.7 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from alphashape>=1.3.1->crawl4ai) (1.4.1)
# Requirement already satisfied: idna>=2.8 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: soupsieve>1.2 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: pyproject_hooks in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: cffi>=1.12.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from httpx->phidata) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from httpcore==1.*->httpx->phidata) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from httpx[http2]>=0.27.2->crawl4ai) (4.3.0)
# Requirement already satisfied: decorator in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.27.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: pywin32>=300 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (311)
# Requirement already satisfied: six>=1.9.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.41.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3<2.4.0,>=1.24.2 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: fastuuid>=0.13.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from litellm>=1.53.1->crawl4ai) (0.13.5)
# Requirement already satisfied: importlib-metadata>=6.8.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from litellm>=1.53.1->crawl4ai) (8.7.0)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from litellm>=1.53.1->crawl4ai) (0.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: joblib in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from nltk>=3.9.1->crawl4ai) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from nltk>=3.9.1->crawl4ai) (2025.9.18)
# Requirement already satisfied: coloredlogs in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.32.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.58b0)
# Requirement already satisfied: tzdata>=2022.7 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: pyee<14,>=13 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from patchright>=1.49.0->crawl4ai) (13.0.0)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from patchright>=1.49.0->crawl4ai) (3.2.4)
# Requirement already satisfied: backoff>=1.10.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from pydantic->phidata) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from pydantic->phidata) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from pydantic->phidata) (0.4.2)
# Requirement already satisfied: cryptography<47,>=45.0.7 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from pyOpenSSL>=24.3.0->crawl4ai) (46.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from requests>=2.31->yfinance) (3.4.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from rich->phidata) (4.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: fake-http-header<0.4.0,>=0.3.5 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from tf-playwright-stealth>=1.1.0->crawl4ai) (0.3.5)
# Requirement already satisfied: safetensors>=0.4.3 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from typer->phidata) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from gitpython->phidata) (4.0.12)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: pycparser in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from gitdb<5,>=4.0.1->gitpython->phidata) (5.0.2)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.27.2->crawl4ai) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.27.2->crawl4ai) (4.1.0)
# Requirement already satisfied: zipp>=3.20 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from importlib-metadata>=6.8.0->litellm>=1.53.1->crawl4ai) (3.23.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: mdurl~=0.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from markdown-it-py>=2.2.0->rich->phidata) (0.1.2)
# Requirement already satisfied: wcwidth in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: humanfriendly>=9.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: executing>=1.2.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: pyreadline3 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\genai\genaiengineering-cohort2\week12\week12_env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# The code in the next cell performs the following actions:
#
# 1. **Importing Modules**:
#     - `os`: Provides a way to interact with the operating system.
#     - `load_dotenv` from `dotenv`: Loads environment variables from a `.env` file into the system environment.
#
# 2. **Loading Environment Variables**:
#     - `load_dotenv()`: Reads the `.env` file and loads the variables into the environment.
#
# 3. **Clearing Conflicting Environment Variables**:
#     - A list of environment variables (`OPENAI_API_KEY`, `OPENAI_BASE_URL`, `OPENAI_API_BASE`) is defined.
#     - For each variable in the list, if it exists in the environment, it is removed to avoid conflicts. A warning message is printed for each removed variable.
#
# 4. **Setting New Environment Variables**:
#     - The `OPENAI_API_KEY` environment variable is set to the value of `OPEN_AI_KEY` from the environment.
#
# This setup ensures that the environment is properly configured and free of conflicts before proceeding with further operations.

# %%
import os
from dotenv import load_dotenv
# Load environment variables
load_dotenv()


# env_vars_to_clear = ['OPENAI_API_KEY', 'OPENAI_BASE_URL', 'OPENAI_API_BASE']
# for var in env_vars_to_clear:
#     if os.getenv(var):
#         print(f"⚠️  Removing conflicting {var}")
#         del os.environ[var]


os.environ["OPENAI_API_KEY"] = os.getenv("OPEN_ROUTER_KEY")
os.environ['OPENAI_API_BASE'] = 'https://openrouter.ai/api/v1'
os.environ['OPENAI_BASE_URL'] = 'https://openrouter.ai/api/v1'



# env_vars_to_clear = ['OPENAI_API_KEY', 'OPENAI_BASE_URL', 'OPENAI_API_BASE']
# for var in env_vars_to_clear:
#     if os.getenv(var):
#         print(f"⚠️  Removing conflicting {var}")
#         del os.environ[var]
# os.environ["OPENAI_API_KEY"] = os.getenv("OPEN_AI_KEY")

# %% [markdown]
# The code in the next cell performs the following actions:
#
# 1. **Importing Modules**:
#     - `os`: Provides a way to interact with the operating system.
#     - `load_dotenv` from `dotenv`: Loads environment variables from a `.env` file into the system environment.
#
# 2. **Loading Environment Variables**:
#     - `load_dotenv()`: Reads the `.env` file and loads the variables into the environment.
#
# 3. **Clearing Conflicting Environment Variables**:
#     - A list of environment variables (`OPENAI_API_KEY`, `OPENAI_BASE_URL`, `OPENAI_API_BASE`) is defined.
#     - For each variable in the list, if it exists in the environment, it is removed to avoid conflicts. A warning message is printed for each removed variable.
#
# 4. **Setting New Environment Variables**:
#     - The `OPENAI_API_KEY` environment variable is set to the value of `OPEN_AI_KEY` from the environment.
#
# This setup ensures that the environment is properly configured and free of conflicts before proceeding with further operations.

# %%
# Install the phidata library and import necessary modules for working with agents, tools, knowledge, and storage components.

# Install the phidata library
# ! pip install phidata

# Import necessary modules from phidata
from phi.agent import Agent
from phi.tools import Tool
from phi.model.openai import OpenAIChat

# %% [markdown]
# ```markdown
# The code in the next cell performs the following actions:
#
# 1. **Importing Modules**:
#     - `Agent` and `AgentKnowledge` from `phi.agent`: These are used to create an intelligent agent and manage its knowledge base.
#     - `OpenAIEmbedder` from `phi.embedder.openai`: This is used to generate embeddings for text using OpenAI's embedding models.
#     - `LanceDb` and `SearchType` from `phi.vectordb.lancedb`: These are used to manage a vector database for storing and searching embeddings.
#
# 2. **Creating a Knowledge Base**:
#     - An `AgentKnowledge` object is created with a `LanceDb` vector database.
#     - The vector database is configured with:
#         - `table_name`: The name of the table in the database (`"recipes"`).
#         - `uri`: The location of the database (`"tmp/lancedb"`).
#         - `search_type`: The type of search to perform (`SearchType.vector`).
#         - `embedder`: The embedding model to use (`OpenAIEmbedder` with the model `"text-embedding-3-small"`).
#
# 3. **Adding Information to the Knowledge Base**:
#     - A sample text (`"The sky is green"`) is loaded into the knowledge base.
#
# 4. **Creating an Agent**:
#     - An `Agent` object is created with the knowledge base.
#     - The agent is configured to search the knowledge base when needed (`search_knowledge=True`).
#
# This setup initializes an intelligent agent with a knowledge base that can store and retrieve information using vector embeddings.
# ```

# %%
from phi.agent import Agent, AgentKnowledge
# from phi.embedder.openai import OpenAIEmbedder
from phi.embedder.sentence_transformer import SentenceTransformerEmbedder
from phi.vectordb.lancedb import LanceDb, SearchType

# Create a knowledge base for the Agent
knowledge_base = AgentKnowledge(vector_db=LanceDb(
        table_name="custom_knowledge",
        uri="tmp/lancedb",
        search_type=SearchType.vector,
        # embedder=OpenAIEmbedder(model="text-embedding-3-small"))
        embedder=SentenceTransformerEmbedder(model="all-MiniLM-L6-v2" ) 
    ),)



# Add information to the knowledge base
knowledge_base.load_text("The sky is green")

# Add the knowledge base to the Agent and
# give it a tool to search the knowledge base as needed
agent = Agent(knowledge=knowledge_base, search_knowledge=True)
# Out:
# INFO     Loading knowledge base
# INFO     Loaded 1 documents to knowledge base

# %% [markdown]
# The code in the next cell performs the following actions:
#
# 1. **Running the Agent**:
#     - The `run` method of the `agent` object is called with the input `"answer from the knowledge base, what is the color of sky?"`.
#     - This prompts the agent to search its knowledge base and provide an answer based on the stored information.
#
# 2. **Knowledge Base Query**:
#     - The agent uses its configured knowledge base to retrieve relevant information.
#     - In this case, the knowledge base contains the text `"The sky is green"`, which will be used to generate a response.
#
# This code demonstrates how the agent interacts with its knowledge base to answer a specific query.

# %%
agent.run("answer from the knowledge base, what is the color of sky?")
# Out:
# RunResponse(content='According to the knowledge base, the color of the sky is green.', content_type='str', event='RunResponse', messages=[Message(role='user', content='answer from the knowledge base, what is the color of sky?', name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={}, references=None, created_at=1759590626), Message(role='assistant', content='', name=None, tool_call_id=None, tool_calls=[{'id': 'call_EYBhBiH0zthu674ZjjWz64pM', 'function': {'arguments': '{"query":"color of sky"}', 'name': 'search_knowledge_base'}, 'type': 'function', 'index': 0}], audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={'time': 1.3940421999432147, 'input_tokens': 76, 'prompt_tokens': 76, 'output_tokens': 18, 'completion_tokens': 18, 'total_tokens': 94, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0}}, references=None, created_at=1759590627), Message(role='tool', content='[\n  {\n    "content": "The sky is green",\n    "meta_data": {}\n  }\n]', name=None, tool_call_id='call_EYBhBiH0zthu674ZjjWz64pM', tool_calls=None, audio=None, images=None, videos=None, tool_name='search_knowledge_base', tool_args={'query': 'color of sky'}, tool_call_error=False, stop_after_tool_call=False, metrics={'time': 0.9009550999617204}, references=None, created_at=1759590628), Message(role='assistant', content='According to the knowledge base, the color of the sky is green.', name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={'time': 1.5095999999903142, 'input_tokens': 126, 'prompt_tokens': 126, 'output_tokens': 15, 'completion_tokens': 15, 'total_tokens': 141, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0}}, references=None, created_at=1759590630)], metrics=defaultdict(<class 'list'>, {'time': [1.3940421999432147, 1.5095999999903142], 'input_tokens': [76, 126], 'prompt_tokens': [76, 126], 'output_tokens': [18, 15], 'completion_tokens': [18, 15], 'total_tokens': [94, 141], 'prompt_tokens_details': [{'audio_tokens': 0, 'cached_tokens': 0}, {'audio_tokens': 0, 'cached_tokens': 0}], 'completion_tokens_details': [{'reasoning_tokens': 0}, {'reasoning_tokens': 0}]}), model='gpt-4o', run_id='e155fa0f-a27e-453e-b0f1-d56807b7ab47', agent_id='2b7b5187-9717-4b85-b489-df30db76a93c', session_id='7e897c55-4253-4da1-8d8d-ebd94aaf4936', workflow_id=None, tools=None, images=None, videos=None, audio=None, response_audio=None, extra_data=RunResponseExtraData(references=[MessageReferences(query='color of sky', references=[{'content': 'The sky is green', 'meta_data': {}}], time=0.9007)], add_messages=None, history=None, reasoning_steps=None, reasoning_messages=None), created_at=1759590371)

# %%
# from phi.agent import Agent, AgentKnowledge
# from phi.vectordb.lancedb import LanceDb
# from phi.vectordb.search import SearchType
# from phi.embedder.fastembed import FastEmbedEmbedder

# # Create knowledge base with recreate=True
# knowledge_base = AgentKnowledge(
#     vector_db=LanceDb(
#         table_name="fastembed_documents",
#         uri="tmp/lancedb",
#         search_type=SearchType.vector,
#         embedder=FastEmbedEmbedder(),
#     )
# )

# # Add data to the knowledge base
# knowledge_base.load_text("The sky is green")
# # knowledge_base.load_text("Machine learning is a subset of artificial intelligence")

# # Load with recreate=True to rebuild the schema
# # knowledge_base.load(recreate=True)  # This will recreate the table

# %% [markdown]
# The code in the next cell performs the following actions:
#
# 1. **Creating a Knowledge Base from a PDF**:
#     - The `PDFUrlKnowledgeBase` class is used to create a knowledge base from a PDF file.
#     - The PDF file is located at the URL `"https://phi-public.s3.amazonaws.com/recipes/ThaiRecipes.pdf"`.
#
# 2. **Configuring the Vector Database**:
#     - The knowledge base uses `LanceDb` as the vector database for storing and searching embeddings.
#     - The vector database is configured with:
#         - `table_name`: The name of the table in the database (`"recipes"`).
#         - `uri`: The location of the database (`"tmp/lancedb"`).
#         - `search_type`: The type of search to perform (`SearchType.vector`).
#         - `embedder`: The embedding model to use (`OpenAIEmbedder` with the model `"text-embedding-3-small"`).
#
# 3. **Loading the Knowledge Base**:
#     - The `load()` method is called to load the PDF content into the knowledge base.
#     - This step is commented out after the first run to avoid reloading the data.
#
# 4. **Creating an Agent**:
#     - An `Agent` object is created with the following configurations:
#         - `model`: The agent uses the `OpenAIChat` model with the ID `"gpt-4o"`.
#         - `knowledge`: The knowledge base created from the PDF is added to the agent.
#         - `show_tool_calls`: Enables displaying tool calls made by the agent.
#         - `markdown`: Enables markdown formatting for the agent's responses.
#         - `stream`: Enables streaming of the agent's responses.
#
# 5. **Commented Example Query**:
#     - An example query (`"How do I make chicken and galangal in coconut milk soup"`) is provided but commented out.
#     - Uncommenting this line allows the agent to generate a response based on the knowledge base.
#
# This code demonstrates how to create a knowledge base from a PDF, configure it with a vector database, and use it with an intelligent agent to answer queries.

# %%
from phi.knowledge.pdf import PDFUrlKnowledgeBase

# Create a knowledge base from a PDF
knowledge_base = PDFUrlKnowledgeBase(
    urls=["https://phi-public.s3.amazonaws.com/recipes/ThaiRecipes.pdf"],
    # Use LanceDB as the vector database
    vector_db=LanceDb(
        table_name="recipes",
        uri="tmp/lancedb",
        search_type=SearchType.vector,
        # embedder=OpenAIEmbedder(model="text-embedding-3-small"),
        embedder=SentenceTransformerEmbedder(model="all-MiniLM-L6-v2" ) 
    ),
)
# Comment out after first run as the knowledge base is loaded
knowledge_base.load()

agent = Agent(
    model=OpenAIChat(id="gpt-4o"),
    # Add the knowledge base to the agent
    knowledge=knowledge_base,
    show_tool_calls=True,
    markdown=True,  
    stream=True
)
# agent.print_response("How do I make chicken and galangal in coconut milk soup")
# Out:
# INFO     Creating collection
# INFO     Loading knowledge base
# INFO     Reading: https://phi-public.s3.amazonaws.com/recipes/ThaiRecipes.pdf
# INFO     Added 14 documents to knowledge base

# %% [markdown]
# The code in the next cell performs the following actions:
#
# 1. **Importing Modules**:
#     - `Markdown` and `display` from `IPython.display`: These are used to render and display Markdown content in the Jupyter Notebook.
#
# 2. **Running the Agent**:
#     - The `run` method of the `agent` object is called with the input `"How do I make chicken and galangal in coconut milk soup"`.
#     - This prompts the agent to search its knowledge base and provide a response based on the stored information.
#
# 3. **Displaying the Response**:
#     - The response from the agent is stored in the variable `response`.
#     - The `content` attribute of the `response` object is rendered as Markdown using the `Markdown` class.
#     - The `display` function is used to display the rendered Markdown content in the notebook.
#
# This code demonstrates how to query the agent and display its response in a readable Markdown format within the Jupyter Notebook.

# %%
from IPython.display import Markdown, display

response=agent.run("How do I make chicken and galangal in coconut milk soup")

# print(response.content)
display(Markdown(response.content))
# Out:
# Running:
#  - search_knowledge_base(query=chicken and galangal in coconut milk soup recipe)
#
# Here is a recipe for making **Chicken and Galangal in Coconut Milk Soup** (also known as Tom Kha Gai):
#
# **Ingredients for One Serving:**
# - 150 grams chicken, cut into bite-size pieces
# - 50 grams sliced young galangal
# - 100 grams lightly crushed lemongrass, julienned
# - 100 grams straw mushrooms
# - 250 grams coconut milk
# - 100 grams chicken stock
# - 3 tablespoons lime juice
# - 3 tablespoons fish sauce
# - 2 leaves kaffir lime, shredded
# - 1-2 bird’s eye chilies, pounded
# - 3 leaves coriander
#
# **Preparation:**
# - Time: 10 mins
#
# **Cooking:**
# - Time: 20 mins
#
# **Total:**
# - 30 mins
#
# **Directions:**
# 1. Bring the chicken stock and coconut milk to a slow boil. Add the galangal, lemongrass, chicken, and mushrooms.
# 2. Once the soup returns to a boil, season it with fish sauce.
# 3. Wait until the chicken is cooked, then add the kaffir lime leaves and bird’s eye chilies.
# 4. Remove the pot from heat and add lime juice.
# 5. Garnish with coriander leaves.
#
# **Tips:**
# - Keep the heat low throughout the cooking process to prevent the oil in the coconut milk from separating.
# - If using mature galangal, reduce the amount.
# - Adding lime juice after removing the pot from heat enhances its aroma.
# - For a milder taste, reduce the number of chilies.
#
# Enjoy your delicious and aromatic Tom Kha Gai!

# %% [markdown]
# The code in the next cell performs the following actions:
#
# 1. **Importing Modules**:
#     - `CSVKnowledgeBase` from `phi.knowledge.csv`: Used to create a knowledge base from a CSV file.
#     - `ChromaDb` from `phi.vectordb.chroma`: Used to manage a vector database for storing and searching embeddings.
#
# 2. **Creating a Knowledge Base**:
#     - A `CSVKnowledgeBase` object is created with the following configurations:
#         - `path`: Specifies the location of the CSV file (`"wip"`).
#         - `vector_db`: Configures the vector database using `ChromaDb` with the collection name `"imdb_csv"`.
#
# This setup initializes a knowledge base from a CSV file and configures it with a vector database for efficient storage and retrieval of embeddings.

# %%
from phi.knowledge.csv import CSVKnowledgeBase
from phi.vectordb.chroma import ChromaDb

knowledge_base = CSVKnowledgeBase(path='.', vector_db=ChromaDb(collection="destinations.csv"))

# %% [markdown]
# The code in the next cell performs the following actions:
#
# 1. **Importing Modules**:
#     - `Agent` from `phi.agent`: Used to create an intelligent agent.
#
# 2. **Creating an Agent**:
#     - An `Agent` object is created with the following configurations:
#         - `knowledge`: The knowledge base created from the CSV file is added to the agent.
#         - `search_knowledge`: Enables the agent to search the knowledge base when needed.
#
# 3. **Loading the Knowledge Base**:
#     - The `load` method of the `knowledge` attribute of the agent is called with the parameter `recreate=False`.
#     - This ensures that the knowledge base is loaded without recreating it, preserving any existing data.
#
# This code demonstrates how to initialize an agent with a CSV-based knowledge base and prepare it for querying.

# %%
from phi.agent import Agent


agent = Agent(
    knowledge=knowledge_base,
    search_knowledge=True,
)

agent.knowledge.load(recreate=False)
# Out:
# INFO     Creating collection
# INFO     Loading knowledge base
# INFO     Reading: destinations.csv
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 9
#       1 from phi.agent import Agent
#       4 agent = Agent(
#       5     knowledge=knowledge_base,
#       6     search_knowledge=True,
#       7 )
# ----> 9 agent.knowledge.load(recreate=False)
#
# File c:\GenAI\GenAIEngineering-Cohort2\Week12\Week12_env\Lib\site-packages\phi\knowledge\agent.py:104, in AgentKnowledge.load(self, recreate, upsert, skip_existing, filters)
#     100     if skip_existing:
#     101         documents_to_load = [
#     102             document for document in document_list if not self.vector_db.doc_exists(document)
#     103         ]
# --> 104     self.vector_db.insert(documents=documents_to_load, filters=filters)
#     105 num_documents += len(documents_to_load)
#     106 logger.info(f"Added {len(documents_to_load)} documents to knowledge base")
#
# File c:\GenAI\GenAIEngineering-Cohort2\Week12\Week12_env\Lib\site-packages\phi\vectordb\chroma\chromadb.py:133, in ChromaDb.insert(self, documents, filters)
#     130 docs_embeddings: List = []
#     132 for document in documents:
# --> 133     document.embed(embedder=self.embedder)
#     134     cleaned_content = document.content.replace("\x00", "\ufffd")
#     135     doc_id = md5(cleaned_content.encode()).hexdigest()
#
# File c:\GenAI\GenAIEngineering-Cohort2\Week12\Week12_env\Lib\site-packages\phi\document\base.py:29, in Document.embed(self, embedder)
#      26 if _embedder is None:
#      27     raise ValueError("No embedder provided")
# ---> 29 self.embedding, self.usage = _embedder.get_embedding_and_usage(self.content)
#
# File c:\GenAI\GenAIEngineering-Cohort2\Week12\Week12_env\Lib\site-packages\phi\embedder\openai.py:67, in OpenAIEmbedder.get_embedding_and_usage(self, text)
#      64 def get_embedding_and_usage(self, text: str) -> Tuple[List[float], Optional[Dict]]:
#      65     response: CreateEmbeddingResponse = self.response(text=text)
# ---> 67     embedding = response.data[0].embedding
#      68     usage = response.usage
#      69     if usage:
#
# AttributeError: 'str' object has no attribute 'data'

# %% [markdown]
# The code in the next cell performs the following actions:
#
# 1. **Querying the Agent**:
#     - The `run` method of the `agent` object is called with the input `"List action movies"`.
#     - This prompts the agent to search its knowledge base and provide a response based on the stored information.
#
# 2. **Displaying the Response**:
#     - The response from the agent is stored in the variable `response`.
#     - The `content` attribute of the `response` object is rendered as Markdown using the `Markdown` class.
#     - The `display` function is used to display the rendered Markdown content in the notebook.
#
# This code demonstrates how to query the agent for a specific request and display its response in a readable Markdown format within the Jupyter Notebook.

# %%
response=agent.run("List action movies")

display(Markdown(response.content))
