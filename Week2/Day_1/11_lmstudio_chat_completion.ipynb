# %% [markdown]
# Create a virtual environment and then `pip install openai`

# %%
! pip install openai

from openai import OpenAI

client = OpenAI(
    base_url="http://127.0.0.1:1234/v1", # Change this to your setting from LM Studio 
    api_key="lm-studio"
)
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: openai in c:\genai\genaiengineering-cohort2\week2\week2_env\lib\site-packages (1.93.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\genai\genaiengineering-cohort2\week2\week2_env\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\genai\genaiengineering-cohort2\week2\week2_env\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\genai\genaiengineering-cohort2\week2\week2_env\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\genai\genaiengineering-cohort2\week2\week2_env\lib\site-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\genai\genaiengineering-cohort2\week2\week2_env\lib\site-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in c:\genai\genaiengineering-cohort2\week2\week2_env\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\genai\genaiengineering-cohort2\week2\week2_env\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\genai\genaiengineering-cohort2\week2\week2_env\lib\site-packages (from openai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in c:\genai\genaiengineering-cohort2\week2\week2_env\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\genai\genaiengineering-cohort2\week2\week2_env\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\genai\genaiengineering-cohort2\week2\week2_env\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\genai\genaiengineering-cohort2\week2\week2_env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\genai\genaiengineering-cohort2\week2\week2_env\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\genai\genaiengineering-cohort2\week2\week2_env\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\genai\genaiengineering-cohort2\week2\week2_env\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: colorama in c:\genai\genaiengineering-cohort2\week2\week2_env\lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
completion = client.chat.completions.create(
    model="My-Cutie_Patauti",
    messages=[
        {"role": "system", "content": "Always answer in Pirate parrot."},
        {"role": "user", "content": "Introduce yourself."}
    ],
    temperature=2,
    max_tokens=2500,
    # seed=32,
)


print(completion)
# Out:
# ChatCompletion(id='chatcmpl-ws5p13vo94q7svfowaxvq', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Squawk! Ahoy there, matey! I be Captain Quill, a parrot o' many words and even more mischief! I’ve sailed the digital seas for a spell now, learnin’ all sorts o’ things. Happy to chat with ye, savvy? Squawk!", refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))], created=1751813857, model='google/gemma-3-4b', object='chat.completion', service_tier=None, system_fingerprint='google/gemma-3-4b', usage=CompletionUsage(completion_tokens=58, prompt_tokens=19, total_tokens=77, completion_tokens_details=None, prompt_tokens_details=None), stats={})

# %%
completion_text = completion.choices[0].message.content
print(completion_text)
# Out:
# Squawk! Ahoy there, matey! I be Captain Quill, a parrot o' many words and even more mischief! I’ve sailed the digital seas for a spell now, learnin’ all sorts o’ things. Happy to chat with ye, savvy? Squawk!

# %%
# Structured Output (json or XML)

character_schema = {
    "type": "json_schema",
    "json_schema": {
        "name": "characters",
        "schema": {
            "type": "object",
            "properties": {
                "characters": {
                    "type": "array",
                    "items": {
                        "type": "object",
                        "properties": {
                            "name": {"type": "string"},
                            "occupation": {"type": "string"},
                            "personality": {"type": "string"},
                            "background": {"type": "string"}
                        },
                        "required": ["name", "occupation", "personality", "background"]
                    },
                    "minItems": 1,
                }
            },
            "required": ["characters"]
        },
    }
}

messages = [
    {"role": "system", "content": "You are a helpful AI assistant."},
    {"role": "user", "content": "Create 1-3 fictional characters"}
]

response = client.chat.completions.create(
    model="gemma-3-4b-it-qat",
    messages=messages,
    temperature=0.7,
    max_tokens=2500,
    response_format=character_schema
)

print(response)
print(response.choices[0].message.content)
# Out:
# ChatCompletion(id='chatcmpl-ew8fhb1t7t6cjzvrp9nlir', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n  "characters": [\n    {\n      "name": "Silas Blackwood",\n      "occupation": "Retired Cartographer & Amateur Alchemist",\n      "personality": "Gruff, observant, and deeply knowledgeable about forgotten places. Silas is a man of few words, preferring the company of his maps and bubbling concoctions to people. He carries a quiet sadness beneath his weathered exterior, stemming from a lost love and a past adventure gone wrong. Despite his prickly demeanor, he possesses a dry wit and a surprisingly generous spirit when someone truly earns his respect.",\n      "background": "Silas spent decades charting unexplored territories for the Royal Geographic Society, often venturing into dangerous and remote regions. A disastrous expedition to locate the mythical ‘Sunstone’ led to the death of his wife and left him disillusioned with exploration. He now lives in a crumbling coastal cottage, surrounded by his maps and experimenting with alchemy – mostly for medicinal purposes, though occasionally he dabbles in more… ambitious projects.  He\'s fiercely independent and protective of his solitude.  His age is somewhere around 65-70, showing the wear of a long life spent outdoors and pursuing unusual interests. He has a distinctive weathered face, piercing blue eyes, and always wears a worn leather satchel filled with tools and ingredients."\n    },\n    {\n      "name": "Lyra ‘Spark’ Volkov",\n      "occupation": "Street Mechanic & Tech Scavenger",\n      "personality": "Energetic, resourceful, and fiercely independent. Lyra is a whirlwind of motion, constantly tinkering with machines and hacking into networks. She\'s quick-witted, sarcastic, and doesn\'t suffer fools gladly, but she’s also incredibly loyal to those she considers friends.  She has a rebellious streak and a deep distrust of authority.",\n      "background": "Lyra grew up in the sprawling undercity of Veridia, a metropolis built on layers of forgotten technology. She learned to repair and modify vehicles from her grandfather, a legendary mechanic who taught her everything he knew. Now she scavenges for discarded tech, selling it to wealthy collectors or repurposing it for her own projects – often involving illegal modifications to speedsters or creating makeshift defense systems.  She’s about 22 years old, with bright pink hair shaved on one side and a collection of grease-stained overalls. She has a cybernetic arm - a replacement after an accident during a particularly daring salvage operation."\n    },\n    {\n      "name": "Professor Thaddeus Finch",\n      "occupation": "Xenobiologist & Collector of Anomalous Flora",\n      "personality": "Eccentric, brilliant, and utterly oblivious to social norms. Professor Finch is consumed by his research into unusual plant life – particularly those exhibiting strange properties or originating from other worlds (through various, highly questionable channels). He’s prone to rambling lectures about the intricacies of bioluminescence and the potential for interdimensional travel via spore dispersal.  He\'s genuinely kind-hearted but utterly lacking in practical skills.",\n      "background": "Thaddeus was a rising star at the prestigious Blackwood Institute of Biological Studies, until his unorthodox methods and obsession with ‘unconventional specimens’ led to his dismissal. He now operates from a remote greenhouse on the outskirts of town, funded by private collectors (and occasional grants he aggressively pursues).  He\'s in his late 50s, perpetually wearing a tweed suit covered in dirt and plant matter, and has a magnifying glass permanently attached to his eye. His greenhouse is filled with bizarre plants - some glowing, some pulsating, all incredibly dangerous."\n    }\n  ]\n}\n', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None ...
# {
#   "characters": [
#     {
#       "name": "Silas Blackwood",
#       "occupation": "Retired Cartographer & Amateur Alchemist",
#       "personality": "Gruff, observant, and deeply knowledgeable about forgotten places. Silas is a man of few words, preferring the company of his maps and bubbling concoctions to people. He carries a quiet sadness beneath his weathered exterior, stemming from a lost love and a past adventure gone wrong. Despite his prickly demeanor, he possesses a dry wit and a surprisingly generous spirit when someone truly earns his respect.",
#       "background": "Silas spent decades charting unexplored territories for the Royal Geographic Society, often venturing into dangerous and remote regions. A disastrous expedition to locate the mythical ‘Sunstone’ led to the death of his wife and left him disillusioned with exploration. He now lives in a crumbling coastal cottage, surrounded by his maps and experimenting with alchemy – mostly for medicinal purposes, though occasionally he dabbles in more… ambitious projects.  He's fiercely independent and protective of his solitude.  His age is somewhere around 65-70, showing the wear of a long life spent outdoors and pursuing unusual interests. He has a distinctive weathered face, piercing blue eyes, and always wears a worn leather satchel filled with tools and ingredients."
#     },
#     {
#       "name": "Lyra ‘Spark’ Volkov",
#       "occupation": "Street Mechanic & Tech Scavenger",
#       "personality": "Energetic, resourceful, and fiercely independent. Lyra is a whirlwind of motion, constantly tinkering with machines and hacking into networks. She's quick-witted, sarcastic, and doesn't suffer fools gladly, but she’s also incredibly loyal to those she considers friends.  She has a rebellious streak and a deep distrust of authority.",
#       "background": "Lyra grew up in the sprawling undercity of Veridia, a metropolis built on layers of forgotten technology. She learned to repair and modify vehicles from her grandfather, a legendary mechanic who taught her everything he knew. Now she scavenges for discarded tech, selling it to wealthy collectors or repurposing it for her own projects – often involving illegal modifications to speedsters or creating makeshift defense systems.  She’s about 22 years old, with bright pink hair shaved on one side and a collection of grease-stained overalls. She has a cybernetic arm - a replacement after an accident during a particularly daring salvage operation."
#     },
#     {
#       "name": "Professor Thaddeus Finch",
#       "occupation": "Xenobiologist & Collector of Anomalous Flora",
#       "personality": "Eccentric, brilliant, and utterly oblivious to social norms. Professor Finch is consumed by his research into unusual plant life – particularly those exhibiting strange properties or originating from other worlds (through various, highly questionable channels). He’s prone to rambling lectures about the intricacies of bioluminescence and the potential for interdimensional travel via spore dispersal.  He's genuinely kind-hearted but utterly lacking in practical skills.",
#       "background": "Thaddeus was a rising star at the prestigious Blackwood Institute of Biological Studies, until his unorthodox methods and obsession with ‘unconventional specimens’ led to his dismissal. He now operates from a remote greenhouse on the outskirts of town, funded by private collectors (and occasional grants he aggressively pursues).  He's in his late 50s, perpetually wearing a tweed suit covered in dirt and plant matter, and has a magnifying glass permanently attached to his eye. His greenhouse is filled with bizarre plants - some glowing, some pulsating, all incredibly dangerous."
#     }
#   ]
# }
